# %% [markdown]
# Este programa despliega un menu para llevar a cabo una operacion matematica dependiendo de su opcion.

# %%
print("CALCULADORA")
print("Elige una opcion")
print("1- SUMA")
print("2- RESTA")
print("3- MULTIPLICACION")
print("4- DIVISION")

x= input("¿Que es lo que quieres hacer? ")
y= float(x)

if (y==1):
   a=input("Introduce el primer numero: ")
   b=input("Introduce el segundo numero: ")
   x=float(a)
   y=float(b)
   resultado= x+y
   print("El resultado de la suma es: ",resultado)

elif (y==2): 
   a=input("Introduce el primer numero: ")
   b=input("introduce el segundo numero: ")
   x=float(a)
   y=float(b)
   resultado= x-y
   print("El resultado de la resta es: ",resultado) 

elif (y==3):
   a=input("Introduce el primer numero: ")
   b=input("Introduce el segundo numero: ")
   x=float(a)
   y=float(b)
   resultado= x*y
   print("El resultado de la multiplicacion es: ",resultado)  

elif (y==4):
   a=float(input("Introduce el primer numero: "))
   b=float(input("Introduce el segundo numero: "))
   while b == 0:
     cero= ''
     b=float(input("Introduce un numero diferente de cero: "))
     resultado= a/b
     print("El resultado de la division es: ", resultado)

else: 
  print("OPCION NO ENCONTRADA REINICE PROGRAMA POR FAVOR")
# Out:
# CALCULADORA
# Elige una opcion
# 1- SUMA
# 2- RESTA
# 3- MULTIPLICACION
# 4- DIVISION
# ¿Que es lo que quieres hacer? 4
# Introduce el primer numero: 1800
# Introduce el segundo numero: 0
# Introduce un numero diferente de cero: 6
# El resultado de la division es:  300.0
