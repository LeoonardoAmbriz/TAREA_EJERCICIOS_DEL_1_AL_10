# %% [markdown]
# Este programa genera un triangulo rectangolo ingresando un numero, este es alto y ancho

# %%
print("GENERADOR DE TRIANGULOS RECTANGULOS")

n=int(input("¿De cuantas unidades enteras quieres tu triangulo? "))

for i in range(n+1):
  
  print('*'*i)
# Out:
# GENERADOR DE TRIANGULOS RECTANGULOS
# ¿De cuantas unidades enteras quieres tu triangulo? 7
#
# *
# **
# ***
# ****
# *****
# ******
# *******
