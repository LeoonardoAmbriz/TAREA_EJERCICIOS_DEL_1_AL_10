# %% [markdown]
# Este programa lee una variable y determina si es par o inpar

# %%
a=int(input("ingrese cualquier numero:"))
if a%2 ==0:
  print("Es un numero par")
else :
  print("El numero es inpar")
