# %% [markdown]
# Este progrma repita la frase que escriba el n numero de veces que desee

# %%
a= str (input("Escriba un enunciado:"))
b= int(input("¿cuantas veces quieres que se repita?  "))
for i in range(b):
  print("",a,end="")
# Out:
# Escriba un enunciado:what's up crack
# ¿cuantas veces quieres que se repita?7
#  what's up crack  what's up crack  what's up crack  what's up crack  what's up crack  what's up crack  what's up crack
