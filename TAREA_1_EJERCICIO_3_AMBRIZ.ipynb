# %% [markdown]
# Este programa calcula el salario de un dia, semana y mes, con ingresar las horas
# trabajadas

# %%
a=int (input("Escribe cuantas horas haz trabajado: "))
b=150

c= a*b*1
d= a*b*5
e= a*b*20

print("salario de un dia:",c)
print("salario de una semana:",d)
print("salario de un mes:",e)
# Out:
# Escribe cuantas horas haz trabajado: 7
# salario de un dia: 1050
# salario de una semana: 5250
# salario de un mes: 21000
