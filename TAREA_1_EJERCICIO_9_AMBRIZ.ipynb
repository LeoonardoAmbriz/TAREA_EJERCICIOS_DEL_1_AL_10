# %% [markdown]
# Este proframa calcula el factorial del numero que usted ingrese

# %%
print("CALCULO DE NUMEROS FACTORIALES")

numero = int(input("¿De que numero entero quieres calcular su factoral? "))

factorial = 1
for n in range(1, (numero+1)):
   factorial = factorial * n

print("Su numero factorial es: ", factorial)
# Out:
# CALCULO DE NUMEROS FACTORIALES
# ¿De que numero entero quieres calcular su factoral? 4
# Su numero factorial es:  24
